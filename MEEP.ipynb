# %% [markdown]
# <a href="https://colab.research.google.com/github/MaansAndersson/colab_test/blob/main/MEEP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook installs MEEP for use in the course DD2370/FDD3270 at KTH.
# It contains tools for MEEP and Visualization. If you find an error, or have any question pealse write in the Canvas page.

# %%
# Set up miniconda

# !MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# !MINICONDA_PREFIX=/usr/local
#!wget https://repo.anaconda.com/miniconda/$MINICONDA_INSTALLER_SCRIPT
# !wget https://repo.anaconda.com/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh
#!chmod +x $MINICONDA_INSTALLER_SCRIPT
# !chmod +x Miniconda3-4.5.4-Linux-x86_64.sh
#!./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# !./Miniconda3-4.5.4-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# --2022-09-30 14:08:44--  https://repo.anaconda.com/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58468498 (56M) [application/x-sh]
# Saving to: ‘Miniconda3-4.5.4-Linux-x86_64.sh’
#
# Miniconda3-4.5.4-Li 100%[===================>]  55.76M  49.3MB/s    in 1.1s
#
# 2022-09-30 14:08:45 (49.3 MB/s) - ‘Miniconda3-4.5.4-Linux-x86_64.sh’ saved [58468498/58468498]
#
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# Python 3.6.5 :: Anaconda, Inc.
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# installing: ruamel_yaml-0.15.37-py36h14c3975_2 ...
# installing: six-1.11.0-py36h372c433_1 ...
# installing: cffi-1.11.5-py36h9745a5d_0 ...
# installing: setuptools-39.2.0-py36_0 ...
# installing: cryptography-2.2.2-py36h14c3975_0 ...
# installing: wheel-0.31.1-py36_0 ...
# installing: pip-10.0.1-py36_0 ...
# installing: pyopenssl-18.0.0-py36_0 ...
# installing: urllib3-1.22-py36hbe7ace6_0 ...
# installing: requests-2.18.4-py36he2e5f8d_1 ...
# installing: conda-4.5.4-py36_0 ...
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local

# %%
# Configure conda
# !conda install --channel defaults conda python=3.7 --yes
# !conda update --channel defaults --all --yes
import sys
_ = (sys.path
        .append("/usr/local/lib/python3.7/site-packages"))
# Out:
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.7
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-package-handling-1.9.0|   py37h5eee18b_0         959 KB
#     tk-8.6.12                  |       h1ccaba5_0         3.3 MB
#     wheel-0.37.1               |     pyhd3eb1b0_0          31 KB
#     pysocks-1.7.1              |           py37_1          27 KB
#     ruamel_yaml-0.15.100       |   py37h27cfd23_0         267 KB
#     cryptography-37.0.1        |   py37h9ce1e76_0         1.5 MB
#     pyopenssl-22.0.0           |     pyhd3eb1b0_0          49 KB
#     libstdcxx-ng-11.2.0        |       h1234567_1         6.1 MB
#     openssl-1.1.1q             |       h7f8727e_0         3.8 MB
#     brotlipy-0.7.0             |py37h27cfd23_1003         350 KB
#     pip-22.1.2                 |   py37h06a4308_0         2.9 MB
#     python-3.7.13              |       h12debd9_0        53.5 MB
#     idna-3.3                   |     pyhd3eb1b0_0          55 KB
#     setuptools-63.4.1          |   py37h06a4308_0         1.4 MB
#     pycparser-2.21             |     pyhd3eb1b0_0          94 KB
#     zlib-1.2.12                |       h5eee18b_3         124 KB
#     ca-certificates-2022.07.19 |       h06a4308_0         131 KB
#     libgcc-ng-11.2.0           |       h1234567_1         8.5 MB
#     conda-22.9.0               |   py37h06a4308_0         958 KB
#     sqlite-3.39.3              |       h5082296_0         1.5 MB
#     requests-2.28.1            |   py37h06a4308_0          91 KB
#     tqdm-4.64.1                |   py37h06a4308_0         122 KB
#     toolz-0.11.2               |     pyhd3eb1b0_0          48 KB
#     libffi-3.3                 |       he6710b0_2          54 KB
#     xz-5.2.6                   |       h5eee18b_0         475 KB
#     readline-8.1.2             |       h7f8727e_1         423 KB
#     pycosat-0.6.3              |   py37h27cfd23_0         108 KB
#     cffi-1.15.1                |   py37h74dc2b5_0         228 KB
#     ncurses-6.3                |       h5eee18b_3         1.1 MB
#     charset-normalizer-2.0.4   |     pyhd3eb1b0_0          33 KB
#     yaml-0.2.5                 |       h7b6447c_0          87 KB
#     urllib3-1.26.11            |   py37h06a4308_0         178 KB
#     ld_impl_linux-64-2.38      |       h1181459_1         732 KB
#     certifi-2022.9.14          |   py37h06a4308_0         158 KB
#     ------------------------------------------------------------
#                                            Total:        89.2 MB
#
# The following NEW packages will be INSTALLED:
#
#     brotlipy:               0.7.0-py37h27cfd23_1003
#     charset-normalizer:     2.0.4-pyhd3eb1b0_0
#     conda-package-handling: 1.9.0-py37h5eee18b_0
#     ld_impl_linux-64:       2.38-h1181459_1
#     toolz:                  0.11.2-pyhd3eb1b0_0
#     tqdm:                   4.64.1-py37h06a4308_0
#
# The following packages will be UPDATED:
#
#     ca-certificates:        2018.03.07-0            --> 2022.07.19-h06a4308_0
#     certifi:                2018.4.16-py36_0        --> 2022.9.14-py37h06a4308_0
#     cffi:                   1.11.5-py36h9745a5d_0   --> 1.15.1-py37h74dc2b5_0
#     conda:                  4.5.4-py36_0            --> 22.9.0-py37h06a4308_0
#     cryptography:           2.2.2-py36h14c3975_0    --> 37.0.1-py37h9ce1e76_0
#     idna:                   2.6-py36h82fb2a8_1      --> 3.3-pyhd3eb1b0_0
#     libffi:                 3.2.1-hd88cf55_4        --> 3.3-he6710b0_2
#     libgcc-ng:              7.2.0-hdf63c60_3        --> 11.2.0-h1234567_1
#     libstdcxx-ng:           7.2.0-hdf63c60_3        --> 11.2.0-h1234567_1
#     ncurses:                6.1-hf484d3e_0          --> 6.3-h5eee18b_3
#     openssl:                1.0.2o-h20670df_0       --> 1.1.1q-h7f8727e_0
#     pip:                    10.0.1-py36_0           --> 22.1.2-py37h06a4308_0
#     pycosat:                0.6.3-py36h0a5515d_0    --> 0.6.3-py37h27cfd23_0
#     pycparser:              2.18-py36hf9f622e_1     --> 2.21-pyhd3eb1b0_0
#     pyopenssl:              18.0.0-py36_0           --> 22.0.0-pyhd3eb1b0_0
#     pysocks:                1.6.8-py36_0            --> 1.7.1-py37_1
#     python:                 3.6.5-hc3d631a_2        --> 3.7.13-h12debd9_0
#     readline:               7.0-ha6073c6_4          --> 8.1.2-h7f8727e_1
#     requests:               2.18.4-py36he2e5f8d_1   --> 2.28.1-py37h06a4308_0
#     ruamel_yaml:            0.15.37-py36h14c3975_2  --> 0.15.100-py37h27cfd23_0
#     setuptools:             39.2.0-py36_0           --> 63.4.1-py37h06a4308_0
#     sqlite:                 3.23.1-he433501_0       --> 3.39.3-h5082296_0
#     tk:                     8.6.7-hc745277_3        --> 8.6.12-h1ccaba5_0
#     urllib3:                1.22-py36hbe7ace6_0     --> 1.26.11-py37h06a4308_0
#     wheel:                  0.31.1-py36_0           --> 0.37.1-pyhd3eb1b0_0
#     xz:                     5.2.4-h14c3975_4        --> 5.2.6-h5eee18b_0
#     yaml:                   0.1.7-had09818_2        --> 0.2.5-h7b6447c_0
#     zlib:                   1.2.11-ha838bed_2       --> 1.2.12-h5eee18b_3
#
#
# Downloading and Extracting Packages
# conda-package-handli |  959 KB | : 100% 1.0/1 [00:00<00:00,  4.66it/s]
# tk-8.6.12            |  3.3 MB | : 100% 1.0/1 [00:00<00:00,  1.12it/s]
# wheel-0.37.1         |   31 KB | : 100% 1.0/1 [00:00<00:00, 20.61it/s]
# pysocks-1.7.1        |   27 KB | : 100% 1.0/1 [00:00<00:00, 21.03it/s]
# ruamel_yaml-0.15.100 |  267 KB | : 100% 1.0/1 [00:00<00:00,  7.16it/s]
# cryptography-37.0.1  |  1.5 MB | : 100% 1.0/1 [00:00<00:00,  1.91it/s]
# pyopenssl-22.0.0     |   49 KB | : 100% 1.0/1 [00:00<00:00, 16.59it/s]
# libstdcxx-ng-11.2.0  |  6.1 MB | : 100% 1.0/1 [00:01<00:00,  1.41s/it]
# openssl-1.1.1q       |  3.8 MB | : 100% 1.0/1 [00:01<00:00,  1.13s/it]
# brotlipy-0.7.0       |  350 KB | : 100% 1.0/1 [00:00<00:00,  9.12it/s]
# pip-22.1.2           |  2.9 MB | : 100% 1.0/1 [00:01<00:00,  1.38s/it]
# python-3.7.13        | 53.5 MB | : 100% 1.0/1 [00:09<00:00,  9.64s/it]
# idna-3.3             |   55 KB | : 100% 1.0/1 [00:00<00:00, 15.25it/s]
# setuptools-63.4.1    |  1.4 MB | : 100% 1.0/1 [00:00<00:00,  1.55it/s]
# pycparser-2.21       |   94 KB | : 100% 1.0/1 [00:00<00:00, 11.91it/s]
# zlib-1.2.12          |  124 KB | : 100% 1.0/1 [00:00<00:00, 14.79it/s]
# ca-certificates-2022 |  131 KB | : 100% 1.0/1 [00:00<00:00, 17.37it/s]
# libgcc-ng-11.2.0     |  8.5 MB | : 100% 1.0/1 [00:01<00:00,  1.72s/it]
# conda-22.9.0         |  958 KB | : 100% 1.0/1 [00:00<00:00,  2.05it/s]
# sqlite-3.39.3        |  1.5 MB | : 100% 1.0/1 [00:00<00:00,  3.07it/s]
# requests-2.28.1      |   91 KB | : 100% 1.0/1 [00:00<00:00, 12.19it/s]
# tqdm-4.64.1          |  122 KB | : 100% 1.0/1 [00:00<00:00,  7.45it/s]
# toolz-0.11.2         |   48 KB | : 100% 1.0/1 [00:00<00:00, 15.17it/s]
# libffi-3.3           |   54 KB | : 100% 1.0/1 [00:00<00:00, 19.35it/s]
# xz-5.2.6             |  475 KB | : 100% 1.0/1 [00:00<00:00,  5.07it/s]
# readline-8.1.2       |  423 KB | : 100% 1.0/1 [00:00<00:00,  5.07it/s]
# pycosat-0.6.3        |  108 KB | : 100% 1.0/1 [00:00<00:00, 15.48it/s]
# cffi-1.15.1          |  228 KB | : 100% 1.0/1 [00:00<00:00,  8.11it/s]
# ncurses-6.3          |  1.1 MB | : 100% 1.0/1 [00:01<00:00,  1.18s/it]
# charset-normalizer-2 |   33 KB | : 100% 1.0/1 [00:00<00:00, 18.84it/s]
# yaml-0.2.5           |   87 KB | : 100% 1.0/1 [00:00<00:00, 13.87it/s]
# urllib3-1.26.11      |  178 KB | : 100% 1.0/1 [00:00<00:00,  6.82it/s]
# ld_impl_linux-64-2.3 |  732 KB | : 100% 1.0/1 [00:00<00:00,  4.22it/s]
# certifi-2022.9.14    |  158 KB | : 100% 1.0/1 [00:00<00:00, 13.15it/s]
# done
# done
# done
# done
# |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::conda-package-handling==1.9.0=py37h5eee18b_0
#   - defaults/linux-64::sqlite==3.39.3=h5082296_0
#   - defaults/noarch::wheel==0.37.1=pyhd3eb1b0_0
#   - defaults/noarch::charset-normalizer==2.0.4=pyhd3eb1b0_0
#   - defaults/linux-64::cryptography==37.0.1=py37h9ce1e76_0
#   - defaults/linux-64::python==3.7.13=h12debd9_0
#   - defaults/linux-64::setuptools==63.4.1=py37h06a4308_0
#   - defaults/linux-64::tqdm==4.64.1=py37h06a4308_0
#   - defaults/linux-64::pysocks==1.7.1=py37_1
#   - defaults/linux-64::chardet==3.0.4=py36h0f667ec_1
#   - defaults/noarch::pycparser==2.21=pyhd3eb1b0_0
#   - defaults/linux-64::brotlipy==0.7.0=py37h27cfd23_1003
#   - defaults/linux-64::urllib3==1.26.11=py37h06a4308_0
#   - defaults/linux-64::certifi==2022.9.14=py37h06a4308_0
#   - defaults/noarch::idna==3.3=pyhd3eb1b0_0
#   - defaults/linux-64::asn1crypto==0.24.0=py36_0
#   - defaults/linux-64::yaml==0.2.5=h7b6447c_0
#   - defaults/linux-64::openssl==1.1.1q=h7f8727e_0
#   - defaults/linux-64::libgcc-ng==11.2.0=h1234567_1
#   - defaults/noarch::toolz==0.11.2=pyhd3eb1b0_0
#   - defaults/linux-64::libedit==3.1.20170329=h6b74fdf_2
#   - defaults/linux-64::requests==2.28.1=py37h06a4308_0
#   - defaults/linux-64::xz==5.2.6=h5eee18b_0
#   - defaults/linux-64::tk==8.6.12=h1ccaba5_0
#   - defaults/linux-64::conda==22.9.0=py37h06a4308_0
#   - defaults/linux-64::ruamel_yaml==0.15.100=py37h27cfd23_0
#   - defaults/linux-64::pycosat==0.6.3=py37h27cfd23_0
#   - defaults/linux-64::ncurses==6.3=h5eee18b_3
#   - defaults/linux-64::readline==8.1.2=h7f8727e_1
#   - defaults/linux-64::zlib==1.2.12=h5eee18b_3
#   - defaults/noarch::pyopenssl==22.0.0=pyhd3eb1b0_0
#   - defaults/linux-64::cffi==1.15.1=py37h74dc2b5_0
#   - defaults/linux-64::libffi==3.3=he6710b0_2
#   - defaults/linux-64::six==1.11.0=py36h372c433_1
#   - defaults/linux-64::pip==22.1.2=py37h06a4308_0
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |             main           3 KB
#     _openmp_mutex-5.1          |            1_gnu          21 KB
#     libgomp-11.2.0             |       h1234567_1         474 KB
#     ------------------------------------------------------------
#                                            Total:         498 KB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main None
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu None
#   libgomp            pkgs/main/linux-64::libgomp-11.2.0-h1234567_1 None
#
#
#
# Downloading and Extracting Packages
# _libgcc_mutex-0.1    | 3 KB      | : 100% 1.0/1 [00:00<00:00,  8.59it/s]
# _openmp_mutex-5.1    | 21 KB     | : 100% 1.0/1 [00:00<00:00, 13.77it/s]
# libgomp-11.2.0       | 474 KB    | : 100% 1.0/1 [00:00<00:00,  8.07it/s]
# done
# done
# done
# Retrieving notices: ...working... done

# %%
# Install MEEP
# !conda install -c conda-forge pymeep --yes
# !conda install -c conda-forge ipython --yes
# Out:
# done
# /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::chardet==3.0.4=py36h0f667ec_1
#   - defaults/linux-64::asn1crypto==0.24.0=py36_0
#   - defaults/linux-64::six==1.11.0=py36h372c433_1
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pymeep
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |       2_kmp_llvm           6 KB  conda-forge
#     asn1crypto-1.5.1           |     pyhd8ed1ab_0          79 KB  conda-forge
#     c-ares-1.18.1              |       h7f98852_0         113 KB  conda-forge
#     ca-certificates-2022.9.24  |       ha878542_0         150 KB  conda-forge
#     cached-property-1.5.2      |       hd8ed1ab_1           4 KB  conda-forge
#     cached_property-1.5.2      |     pyha770c72_1          11 KB  conda-forge
#     certifi-2022.9.24          |     pyhd8ed1ab_0         155 KB  conda-forge
#     chardet-5.0.0              |   py37h89c1867_0         230 KB  conda-forge
#     conda-22.9.0               |   py37h89c1867_1         960 KB  conda-forge
#     fftw-3.3.10                |nompi_hf0379b8_105         2.2 MB  conda-forge
#     gsl-2.7                    |       he838d99_0         3.2 MB  conda-forge
#     h5py-3.7.0                 |nompi_py37hc97082c_100         1.2 MB  conda-forge
#     harminv-1.4.1              |    hbf3b5f1_1007          53 KB  conda-forge
#     hdf5-1.12.1                |nompi_h2386368_104         3.5 MB  conda-forge
#     keyutils-1.6.1             |       h166bdaf_0         115 KB  conda-forge
#     krb5-1.19.3                |       h3790be6_0         1.4 MB  conda-forge
#     libblas-3.9.0              |16_linux64_openblas          13 KB  conda-forge
#     libcblas-3.9.0             |16_linux64_openblas          13 KB  conda-forge
#     libctl-4.5.1               |       h7f98852_0         114 KB  conda-forge
#     libcurl-7.83.1             |       h7bff187_0         342 KB  conda-forge
#     libedit-3.1.20191231       |       he28a2e2_2         121 KB  conda-forge
#     libev-4.33                 |       h516909a_1         104 KB  conda-forge
#     libgcc-ng-12.1.0           |      h8d9b700_16         940 KB  conda-forge
#     libgdsii-0.21              |       h4bd325d_4          85 KB  conda-forge
#     libgfortran-ng-12.1.0      |      h69a702a_16          23 KB  conda-forge
#     libgfortran5-12.1.0        |      hdcd56e2_16         1.8 MB  conda-forge
#     liblapack-3.9.0            |16_linux64_openblas          13 KB  conda-forge
#     libnghttp2-1.47.0          |       hdcd2b5c_1         808 KB  conda-forge
#     libopenblas-0.3.21         |pthreads_h78a6416_3        10.1 MB  conda-forge
#     libssh2-1.10.0             |       haa6b8db_3         234 KB  conda-forge
#     libstdcxx-ng-12.1.0        |      ha89aaad_16         4.3 MB  conda-forge
#     libzlib-1.2.12             |       h166bdaf_3          65 KB  conda-forge
#     llvm-openmp-14.0.4         |       he0ac6c6_0         5.8 MB  conda-forge
#     mpb-1.11.1                 |nompi_h70f4da8_104          66 KB  conda-forge
#     numpy-1.21.6               |   py37h976b520_0         6.1 MB  conda-forge
#     openssl-1.1.1q             |       h166bdaf_0         2.1 MB  conda-forge
#     pymeep-1.24.0              |nompi_py37h1234567_101         1.9 MB  conda-forge
#     python_abi-3.7             |          2_cp37m           4 KB  conda-forge
#     six-1.16.0                 |     pyh6c4a22f_0          14 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        48.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   c-ares             conda-forge/linux-64::c-ares-1.18.1-h7f98852_0 None
#   cached-property    conda-forge/noarch::cached-property-1.5.2-hd8ed1ab_1 None
#   cached_property    conda-forge/noarch::cached_property-1.5.2-pyha770c72_1 None
#   fftw               conda-forge/linux-64::fftw-3.3.10-nompi_hf0379b8_105 None
#   gsl                conda-forge/linux-64::gsl-2.7-he838d99_0 None
#   h5py               conda-forge/linux-64::h5py-3.7.0-nompi_py37hc97082c_100 None
#   harminv            conda-forge/linux-64::harminv-1.4.1-hbf3b5f1_1007 None
#   hdf5               conda-forge/linux-64::hdf5-1.12.1-nompi_h2386368_104 None
#   keyutils           conda-forge/linux-64::keyutils-1.6.1-h166bdaf_0 None
#   krb5               conda-forge/linux-64::krb5-1.19.3-h3790be6_0 None
#   libblas            conda-forge/linux-64::libblas-3.9.0-16_linux64_openblas None
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-16_linux64_openblas None
#   libctl             conda-forge/linux-64::libctl-4.5.1-h7f98852_0 None
#   libcurl            conda-forge/linux-64::libcurl-7.83.1-h7bff187_0 None
#   libev              conda-forge/linux-64::libev-4.33-h516909a_1 None
#   libgdsii           conda-forge/linux-64::libgdsii-0.21-h4bd325d_4 None
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-12.1.0-h69a702a_16 None
#   libgfortran5       conda-forge/linux-64::libgfortran5-12.1.0-hdcd56e2_16 None
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-16_linux64_openblas None
#   libnghttp2         conda-forge/linux-64::libnghttp2-1.47.0-hdcd2b5c_1 None
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.21-pthreads_h78a6416_3 None
#   libssh2            conda-forge/linux-64::libssh2-1.10.0-haa6b8db_3 None
#   libzlib            conda-forge/linux-64::libzlib-1.2.12-h166bdaf_3 None
#   llvm-openmp        conda-forge/linux-64::llvm-openmp-14.0.4-he0ac6c6_0 None
#   mpb                conda-forge/linux-64::mpb-1.11.1-nompi_h70f4da8_104 None
#   numpy              conda-forge/linux-64::numpy-1.21.6-py37h976b520_0 None
#   pymeep             conda-forge/linux-64::pymeep-1.24.0-nompi_py37h1234567_101 None
#   python_abi         conda-forge/linux-64::python_abi-3.7-2_cp37m None
#
# The following packages will be REMOVED:
#
#   libgomp-11.2.0-h1234567_1
#
# The following packages will be UPDATED:
#
#   asn1crypto         pkgs/main/linux-64::asn1crypto-0.24.0~ --> conda-forge/noarch::asn1crypto-1.5.1-pyhd8ed1ab_0 None
#   ca-certificates    pkgs/main::ca-certificates-2022.07.19~ --> conda-forge::ca-certificates-2022.9.24-ha878542_0 None
#   certifi            pkgs/main/linux-64::certifi-2022.9.14~ --> conda-forge/noarch::certifi-2022.9.24-pyhd8ed1ab_0 None
#   chardet            pkgs/main::chardet-3.0.4-py36h0f667ec~ --> conda-forge::chardet-5.0.0-py37h89c1867_0 None
#   conda              pkgs/main::conda-22.9.0-py37h06a4308_0 --> conda-forge::conda-22.9.0-py37h89c1867_1 None
#   libedit            pkgs/main::libedit-3.1.20170329-h6b74~ --> conda-forge::libedit-3.1.20191231-he28a2e2_2 None
#   libgcc-ng          pkgs/main::libgcc-ng-11.2.0-h1234567_1 --> conda-forge::libgcc-ng-12.1.0-h8d9b700_16 None
#   libstdcxx-ng       pkgs/main::libstdcxx-ng-11.2.0-h12345~ --> conda-forge::libstdcxx-ng-12.1.0-ha89aaad_16 None
#   six                pkgs/main/linux-64::six-1.11.0-py36h3~ --> conda-forge/noarch::six-1.16.0-pyh6c4a22f_0 None
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   _libgcc_mutex           pkgs/main::_libgcc_mutex-0.1-main --> conda-forge::_libgcc_mutex-0.1-conda_forge None
#   _openmp_mutex          pkgs/main::_openmp_mutex-5.1-1_gnu --> conda-forge::_openmp_mutex-4.5-2_kmp_llvm None
#   openssl              pkgs/main::openssl-1.1.1q-h7f8727e_0 --> conda-forge::openssl-1.1.1q-h166bdaf_0 None
#
#
#
# Downloading and Extracting Packages
# keyutils-1.6.1       | 115 KB    | : 100% 1.0/1 [00:00<00:00,  5.99it/s]
# libzlib-1.2.12       | 65 KB     | : 100% 1.0/1 [00:00<00:00, 18.16it/s]
# chardet-5.0.0        | 230 KB    | : 100% 1.0/1 [00:00<00:00,  7.69it/s]
# c-ares-1.18.1        | 113 KB    | : 100% 1.0/1 [00:00<00:00, 11.80it/s]
# libopenblas-0.3.21   | 10.1 MB   | : 100% 1.0/1 [00:02<00:00,  2.46s/it]
# pymeep-1.24.0        | 1.9 MB    | : 100% 1.0/1 [00:00<00:00,  1.74it/s]
# libgfortran-ng-12.1. | 23 KB     | : 100% 1.0/1 [00:00<00:00, 16.87it/s]
# libgcc-ng-12.1.0     | 940 KB    | : 100% 1.0/1 [00:00<00:00,  4.92it/s]
# libnghttp2-1.47.0    | 808 KB    | : 100% 1.0/1 [00:00<00:00,  4.97it/s]
# cached-property-1.5. | 4 KB      | : 100% 1.0/1 [00:00<00:00, 20.32it/s]
# libcurl-7.83.1       | 342 KB    | : 100% 1.0/1 [00:00<00:00,  8.59it/s]
# gsl-2.7              | 3.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.14it/s]
# krb5-1.19.3          | 1.4 MB    | : 100% 1.0/1 [00:00<00:00,  2.43it/s]
# libgdsii-0.21        | 85 KB     | : 100% 1.0/1 [00:00<00:00, 15.81it/s]
# libssh2-1.10.0       | 234 KB    | : 100% 1.0/1 [00:00<00:00,  8.26it/s]
# hdf5-1.12.1          | 3.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.28it/s]
# liblapack-3.9.0      | 13 KB     | : 100% 1.0/1 [00:00<00:00, 19.64it/s]
# _libgcc_mutex-0.1    | 3 KB      | : 100% 1.0/1 [00:00<00:00, 20.77it/s]
# cached_property-1.5. | 11 KB     | : 100% 1.0/1 [00:00<00:00, 17.43it/s]
# python_abi-3.7       | 4 KB      | : 100% 1.0/1 [00:00<00:00, 20.01it/s]
# six-1.16.0           | 14 KB     | : 100% 1.0/1 [00:00<00:00, 19.47it/s]
# libblas-3.9.0        | 13 KB     | : 100% 1.0/1 [00:00<00:00, 17.90it/s]
# libev-4.33           | 104 KB    | : 100% 1.0/1 [00:00<00:00, 15.62it/s]
# libgfortran5-12.1.0  | 1.8 MB    | : 100% 1.0/1 [00:00<00:00,  2.24it/s]
# ca-certificates-2022 | 150 KB    | : 100% 1.0/1 [00:00<00:00, 12.94it/s]
# asn1crypto-1.5.1     | 79 KB     | : 100% 1.0/1 [00:00<00:00, 14.22it/s]
# openssl-1.1.1q       | 2.1 MB    | : 100% 1.0/1 [00:00<00:00,  2.24it/s]
# conda-22.9.0         | 960 KB    | : 100% 1.0/1 [00:00<00:00,  2.85it/s]
# certifi-2022.9.24    | 155 KB    | : 100% 1.0/1 [00:00<00:00, 14.93it/s]
# numpy-1.21.6         | 6.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.90s/it]
# libcblas-3.9.0       | 13 KB     | : 100% 1.0/1 [00:00<00:00, 21.80it/s]
# llvm-openmp-14.0.4   | 5.8 MB    | : 100% 1.0/1 [00:01<00:00,  1.08s/it]
# libctl-4.5.1         | 114 KB    | : 100% 1.0/1 [00:00<00:00, 12.49it/s]
# libstdcxx-ng-12.1.0  | 4.3 MB    | : 100% 1.0/1 [00:00<00:00,  1.21it/s]
# _openmp_mutex-4.5    | 6 KB      | : 100% 1.0/1 [00:00<00:00, 15.70it/s]
# fftw-3.3.10          | 2.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.85it/s]
# libedit-3.1.20191231 | 121 KB    | : 100% 1.0/1 [00:00<00:00, 10.37it/s]
# mpb-1.11.1           | 66 KB     | : 100% 1.0/1 [00:00<00:00,  6.86it/s]
# h5py-3.7.0           | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  2.19it/s]
# harminv-1.4.1        | 53 KB     | : 100% 1.0/1 [00:00<00:00, 17.57it/s]
# done
# done
# done
# Retrieving notices: ...working... done
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - ipython
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     backcall-0.2.0             |     pyh9f0ad1d_0          13 KB  conda-forge
#     backports-1.0              |             py_2           4 KB  conda-forge
#     backports.functools_lru_cache-1.6.4|     pyhd8ed1ab_0           9 KB  conda-forge
#     decorator-5.1.1            |     pyhd8ed1ab_0          12 KB  conda-forge
#     ipython-7.33.0             |   py37h89c1867_0         1.1 MB  conda-forge
#     jedi-0.18.1                |     pyhd8ed1ab_2         799 KB  conda-forge
#     matplotlib-inline-0.1.6    |     pyhd8ed1ab_0          12 KB  conda-forge
#     parso-0.8.3                |     pyhd8ed1ab_0          69 KB  conda-forge
#     pexpect-4.8.0              |     pyh9f0ad1d_2          47 KB  conda-forge
#     pickleshare-0.7.5          |          py_1003           9 KB  conda-forge
#     prompt-toolkit-3.0.31      |     pyha770c72_0         254 KB  conda-forge
#     ptyprocess-0.7.0           |     pyhd3deb0d_0          16 KB  conda-forge
#     pygments-2.13.0            |     pyhd8ed1ab_0         821 KB  conda-forge
#     traitlets-5.4.0            |     pyhd8ed1ab_0          85 KB  conda-forge
#     wcwidth-0.2.5              |     pyh9f0ad1d_2          33 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   backcall           conda-forge/noarch::backcall-0.2.0-pyh9f0ad1d_0 None
#   backports          conda-forge/noarch::backports-1.0-py_2 None
#   backports.functoo~ conda-forge/noarch::backports.functools_lru_cache-1.6.4-pyhd8ed1ab_0 None
#   decorator          conda-forge/noarch::decorator-5.1.1-pyhd8ed1ab_0 None
#   ipython            conda-forge/linux-64::ipython-7.33.0-py37h89c1867_0 None
#   jedi               conda-forge/noarch::jedi-0.18.1-pyhd8ed1ab_2 None
#   matplotlib-inline  conda-forge/noarch::matplotlib-inline-0.1.6-pyhd8ed1ab_0 None
#   parso              conda-forge/noarch::parso-0.8.3-pyhd8ed1ab_0 None
#   pexpect            conda-forge/noarch::pexpect-4.8.0-pyh9f0ad1d_2 None
#   pickleshare        conda-forge/noarch::pickleshare-0.7.5-py_1003 None
#   prompt-toolkit     conda-forge/noarch::prompt-toolkit-3.0.31-pyha770c72_0 None
#   ptyprocess         conda-forge/noarch::ptyprocess-0.7.0-pyhd3deb0d_0 None
#   pygments           conda-forge/noarch::pygments-2.13.0-pyhd8ed1ab_0 None
#   traitlets          conda-forge/noarch::traitlets-5.4.0-pyhd8ed1ab_0 None
#   wcwidth            conda-forge/noarch::wcwidth-0.2.5-pyh9f0ad1d_2 None
#
#
#
# Downloading and Extracting Packages
# prompt-toolkit-3.0.3 | 254 KB    | : 100% 1.0/1 [00:00<00:00,  4.08it/s]
# matplotlib-inline-0. | 12 KB     | : 100% 1.0/1 [00:00<00:00, 21.25it/s]
# ipython-7.33.0       | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  2.07it/s]
# backcall-0.2.0       | 13 KB     | : 100% 1.0/1 [00:00<00:00, 21.60it/s]
# parso-0.8.3          | 69 KB     | : 100% 1.0/1 [00:00<00:00, 14.54it/s]
# ptyprocess-0.7.0     | 16 KB     | : 100% 1.0/1 [00:00<00:00, 21.64it/s]
# pygments-2.13.0      | 821 KB    | : 100% 1.0/1 [00:00<00:00,  2.88it/s]
# wcwidth-0.2.5        | 33 KB     | : 100% 1.0/1 [00:00<00:00, 16.20it/s]
# pexpect-4.8.0        | 47 KB     | : 100% 1.0/1 [00:00<00:00, 16.73it/s]
# traitlets-5.4.0      | 85 KB     | : 100% 1.0/1 [00:00<00:00, 14.91it/s]
# pickleshare-0.7.5    | 9 KB      | : 100% 1.0/1 [00:00<00:00, 21.11it/s]
# backports.functools_ | 9 KB      | : 100% 1.0/1 [00:00<00:00, 21.39it/s]
# jedi-0.18.1          | 799 KB    | : 100% 1.0/1 [00:00<00:00,  1.33it/s]
# decorator-5.1.1      | 12 KB     | : 100% 1.0/1 [00:00<00:00, 21.55it/s]
# backports-1.0        | 4 KB      | : 100% 1.0/1 [00:00<00:00, 22.70it/s]
# done
# done
# done
# Retrieving notices: ...working... done

# %%
import meep as mp
from matplotlib import pyplot as plt
import numpy as np
from IPython.core.display import Video
# %matplotlib inline

cell = mp.Vector3(16,16,0)
geometry = [mp.Block(mp.Vector3(12,1,mp.inf),
                     center=mp.Vector3(-2.5,-3.5),
                     material=mp.Medium(epsilon=12)),
            mp.Block(mp.Vector3(1,12,mp.inf),
                     center=mp.Vector3(3.5,2),
                     material=mp.Medium(epsilon=12))]
pml_layers = [mp.PML(1.0)]
resolution = 10

sources = [mp.Source(mp.ContinuousSource(wavelength=2*(11**0.5), width=20),
                     component=mp.Ez,
                     center=mp.Vector3(-7,-3.5),
                     size=mp.Vector3(0,1))]
sim = mp.Simulation(cell_size=cell,
                    boundary_layers=pml_layers,
                    geometry=geometry,
                    sources=sources,
                    resolution=resolution)



f = plt.figure(dpi=150)
sim.plot2D(ax = f.gca())
plt.show()

f = plt.figure(dpi=150)
Animate = mp.Animate2D(sim, fields=mp.Ez, f=f, realtime=False, normalize=True)
sim.run(mp.at_every(0.5,Animate),until=100)
plt.close()
# Out:
#      block, center = (-2.5,-3.5,0)
#           size (12,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (3.5,2,0)
#           size (1,12,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000174999 s
# Working in 2D dimensions.
# Computational cell is 16 x 16 x 0 with resolution 10
#      block, center = (-2.5,-3.5,0)
#           size (12,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (3.5,2,0)
#           size (1,12,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
# time for set_epsilon = 0.070997 s
# -----------
# FloatProgress(value=0.0, description='0% done ')
#      block, center = (-2.5,-3.5,0)
#           size (12,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (3.5,2,0)
#           size (1,12,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
# Normalizing field data...
# run 0 finished at t = 100.0 (2000 timesteps)

# %%
filename = "bent_waveguide.mp4"
fps = 10
Animate.to_mp4(fps,filename)
Video(filename,embed=True)
# Out:
# Generating MP4...
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
import meep as mp
from matplotlib import pyplot as plt
import numpy as np
from IPython.core.display import Video

cell = mp.Vector3(16,8,0)
geometry = [mp.Block(mp.Vector3(mp.inf,1,mp.inf),
                     center=mp.Vector3(),
                     material=mp.Medium(epsilon=12))]

sources = [mp.Source(mp.ContinuousSource(frequency=0.15),
                     component=mp.Ez,
                     center=mp.Vector3(-7,0))]

pml_layers = [mp.PML(1.0)]

resolution = 100
sim = mp.Simulation(cell_size=cell,
                    boundary_layers=pml_layers,
                    geometry=geometry,
                    sources=sources,
                    resolution=resolution)
sim.run(until=200)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00121093 s
# Working in 2D dimensions.
# Computational cell is 16 x 8 x 0 with resolution 100
#      block, center = (0,0,0)
#           size (1e+20,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
# time for set_epsilon = 2.19422 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=200.0)
# Meep progress: 1.21/200.0 = 0.6% done in 4.0s, 657.2s to go
# on time step 243 (time=1.215), 0.0164681 s/step
# Meep progress: 2.505/200.0 = 1.3% done in 8.0s, 631.6s to go
# on time step 502 (time=2.51), 0.0154876 s/step
# Meep progress: 3.935/200.0 = 2.0% done in 12.0s, 598.6s to go
# on time step 789 (time=3.945), 0.0139633 s/step
# Meep progress: 5.4750000000000005/200.0 = 2.7% done in 16.0s, 569.4s to go
# on time step 1097 (time=5.485), 0.0130188 s/step
# Meep progress: 6.845/200.0 = 3.4% done in 20.0s, 565.4s to go
# on time step 1371 (time=6.855), 0.0146741 s/step
# Meep progress: 8.21/200.0 = 4.1% done in 24.0s, 561.6s to go
# on time step 1645 (time=8.225), 0.0146152 s/step
# Meep progress: 9.67/200.0 = 4.8% done in 28.1s, 552.1s to go
# on time step 1937 (time=9.685), 0.0137055 s/step
# Meep progress: 10.955/200.0 = 5.5% done in 32.1s, 553.3s to go
# on time step 2193 (time=10.965), 0.0156448 s/step
# Meep progress: 12.355/200.0 = 6.2% done in 36.1s, 547.9s to go
# on time step 2473 (time=12.365), 0.0143226 s/step
# Meep progress: 13.675/200.0 = 6.8% done in 40.1s, 546.0s to go
# on time step 2738 (time=13.69), 0.0151406 s/step
# Meep progress: 15.055/200.0 = 7.5% done in 44.1s, 541.5s to go
# on time step 3015 (time=15.075), 0.0144742 s/step
# Meep progress: 16.5/200.0 = 8.2% done in 48.1s, 534.8s to go
# on time step 3304 (time=16.52), 0.0138577 s/step
# Meep progress: 17.905/200.0 = 9.0% done in 52.1s, 529.9s to go
# on time step 3585 (time=17.925), 0.0143008 s/step
# Meep progress: 19.295/200.0 = 9.6% done in 56.1s, 525.5s to go
# on time step 3863 (time=19.315), 0.0144293 s/step
# Meep progress: 20.805/200.0 = 10.4% done in 60.1s, 517.7s to go
# on time step 4166 (time=20.83), 0.013221 s/step
# Meep progress: 22.255/200.0 = 11.1% done in 64.1s, 512.0s to go
# on time step 4457 (time=22.285), 0.0137528 s/step
# Meep progress: 23.795/200.0 = 11.9% done in 68.1s, 504.4s to go
# on time step 4766 (time=23.83), 0.0129786 s/step
# Meep progress: 25.16/200.0 = 12.6% done in 72.1s, 501.2s to go
# on time step 5038 (time=25.19), 0.0147622 s/step
# Meep progress: 26.560000000000002/200.0 = 13.3% done in 76.1s, 497.1s to go
# on time step 5320 (time=26.6), 0.0141988 s/step
# Meep progress: 27.94/200.0 = 14.0% done in 80.1s, 493.4s to go
# on time step 5595 (time=27.975), 0.0145891 s/step
# Meep progress: 29.42/200.0 = 14.7% done in 84.1s, 487.8s to go
# on time step 5891 (time=29.455), 0.0135636 s/step
# Meep progress: 30.795/200.0 = 15.4% done in 88.1s, 484.3s to go
# on time step 6168 (time=30.84), 0.0144925 s/step
# Meep progress: 32.17/200.0 = 16.1% done in 92.2s, 480.8s to go
# on time step 6443 (time=32.215), 0.0145481 s/step
# Meep progress: 33.45/200.0 = 16.7% done in 96.2s, 478.8s to go
# on time step 6700 (time=33.5), 0.0155979 s/step
# Meep progress: 34.910000000000004/200.0 = 17.5% done in 100.2s, 473.6s to go
# on time step 6991 (time=34.955), 0.0137769 s/step
# Meep progress: 36.36/200.0 = 18.2% done in 104.2s, 468.8s to go
# on time step 7282 (time=36.41), 0.0137577 s/step
# Meep progress: 37.81/200.0 = 18.9% done in 108.2s, 464.0s to go
# on time step 7572 (time=37.86), 0.0138381 s/step
# Meep progress: 39.27/200.0 = 19.6% done in 112.2s, 459.2s to go
# on time step 7864 (time=39.32), 0.0137352 s/step
# Meep progress: 40.725/200.0 = 20.4% done in 116.2s, 454.4s to go
# on time step 8156 (time=40.78), 0.0137351 s/step
# Meep progress: 42.02/200.0 = 21.0% done in 120.2s, 451.9s to go
# on time step 8414 (time=42.07), 0.0155053 s/step
# Meep progress: 43.315/200.0 = 21.7% done in 124.2s, 449.3s to go
# on time step 8674 (time=43.37), 0.0154059 s/step
# Meep progress: 44.77/200.0 = 22.4% done in 128.2s, 444.5s to go
# on time step 8963 (time=44.815), 0.0138688 s/step
# Meep progress: 46.065/200.0 = 23.0% done in 132.2s, 441.8s to go
# on time step 9224 (time=46.12), 0.0153663 s/step
# Meep progress: 47.445/200.0 = 23.7% done in 136.2s, 438.0s to go
# on time step 9500 (time=47.5), 0.0145501 s/step
# Meep progress: 48.885/200.0 = 24.4% done in 140.2s, 433.5s to go
# on time step 9789 (time=48.945), 0.0138514 s/step
# Meep progress: 50.285000000000004/200.0 = 25.1% done in 144.2s, 429.4s to go
# on time step 10068 (time=50.34), 0.0143644 s/step
# Meep progress: 51.725/200.0 = 25.9% done in 148.2s, 424.9s to go
# on time step 10359 (time=51.795), 0.0137734 s/step
# Meep progress: 53.14/200.0 = 26.6% done in 152.2s, 420.7s to go
# on time step 10639 (time=53.195), 0.0143063 s/step
# Meep progress: 54.415/200.0 = 27.2% done in 156.2s, 418.0s to go
# on time step 10897 (time=54.485), 0.0155522 s/step
# Meep progress: 55.975/200.0 = 28.0% done in 160.3s, 412.3s to go
# on time step 11209 (time=56.045), 0.0128251 s/step
# Meep progress: 57.44/200.0 = 28.7% done in 164.3s, 407.7s to go
# on time step 11502 (time=57.51), 0.0136571 s/step
# Meep progress: 58.83/200.0 = 29.4% done in 168.3s, 403.8s to go
# on time step 11780 (time=58.9), 0.0144234 s/step
# Meep progress: 60.21/200.0 = 30.1% done in 172.3s, 400.0s to go
# on time step 12056 (time=60.28), 0.0145083 s/step
# Meep progress: 61.77/200.0 = 30.9% done in 176.3s, 394.5s to go
# on time step 12369 (time=61.845), 0.0127975 s/step
# Meep progress: 63.165/200.0 = 31.6% done in 180.3s, 390.6s to go
# on time step 12645 (time=63.225), 0.0145481 s/step
# Meep progress: 64.54/200.0 = 32.3% done in 184.3s, 386.8s to go
# on time step 12923 (time=64.615), 0.0144001 s/step
# Meep progress: 65.94/200.0 = 33.0% done in 188.3s, 382.8s to go
# on time step 13204 (time=66.02), 0.0142594 s/step
# Meep progress: 67.33500000000001/200.0 = 33.7% done in 192.3s, 378.9s to go
# on time step 13483 (time=67.415), 0.014374 s/step
# Meep progress: 68.795/200.0 = 34.4% done in 196.3s, 374.4s to go
# on time step 13775 (time=68.875), 0.0137017 s/step
# Meep progress: 70.27/200.0 = 35.1% done in 200.3s, 369.8s to go
# on time step 14069 (time=70.345), 0.0136055 s/step
# Meep progress: 71.72/200.0 = 35.9% done in 204.3s, 365.5s to go
# on time step 14356 (time=71.78), 0.0139763 s/step
# Meep progress: 73.035/200.0 = 36.5% done in 208.3s, 362.2s to go
# on time step 14619 (time=73.095), 0.0152477 s/step
# Meep progress: 74.43/200.0 = 37.2% done in 212.3s, 358.2s to go
# on time step 14899 (time=74.495), 0.0143204 s/step
# Meep progress: 75.905/200.0 = 38.0% done in 216.3s, 353.7s to go
# on time step 15199 (time=75.995), 0.0133652 s/step
# Meep progress: 77.385/200.0 = 38.7% done in 220.4s, 349.2s to go
# on time step 15490 (time=77.45), 0.0137484 s/step
# Meep progress: 78.785/200.0 = 39.4% done in 224.4s, 345.2s to go
# on time step 15771 (time=78.855), 0.01428 s/step
# Meep progress: 80.155/200.0 = 40.1% done in 228.4s, 341.5s to go
# on time step 16047 (time=80.235), 0.0145249 s/step
# Meep progress: 81.41/200.0 = 40.7% done in 232.4s, 338.5s to go
# on time step 16297 (time=81.485), 0.0160511 s/step
# Meep progress: 82.885/200.0 = 41.4% done in 236.4s, 334.0s to go
# on time step 16593 (time=82.965), 0.0135648 s/step
# Meep progress: 84.275/200.0 = 42.1% done in 240.4s, 330.1s to go
# on time step 16871 (time=84.355), 0.0144156 s/step
# Meep progress: 85.655/200.0 = 42.8% done in 244.4s, 326.3s to go
# on time step 17147 (time=85.735), 0.014497 s/step
# Meep progress: 86.88/200.0 = 43.4% done in 248.4s, 323.4s to go
# on time step 17392 (time=86.96), 0.0163912 s/step
# Meep progress: 88.26/200.0 = 44.1% done in 252.4s, 319.6s to go
# on time step 17669 (time=88.345), 0.0144934 s/step
# Meep progress: 89.635/200.0 = 44.8% done in 256.4s, 315.7s to go
# on time step 17944 (time=89.72), 0.0145557 s/step
# Meep progress: 90.845/200.0 = 45.4% done in 260.4s, 312.9s to go
# on time step 18186 (time=90.93), 0.016572 s/step
# Meep progress: 92.21000000000001/200.0 = 46.1% done in 264.4s, 309.1s to go
# on time step 18460 (time=92.3), 0.0146631 s/step
# Meep progress: 93.56/200.0 = 46.8% done in 268.4s, 305.4s to go
# on time step 18730 (time=93.65), 0.0148652 s/step
# Meep progress: 94.915/200.0 = 47.5% done in 272.5s, 301.6s to go
# on time step 19008 (time=95.04), 0.0144253 s/step
# Meep progress: 96.345/200.0 = 48.2% done in 276.5s, 297.4s to go
# on time step 19292 (time=96.46), 0.014139 s/step
# Meep progress: 97.645/200.0 = 48.8% done in 280.5s, 294.0s to go
# on time step 19550 (time=97.75), 0.0155055 s/step
# Meep progress: 99.11500000000001/200.0 = 49.6% done in 284.5s, 289.5s to go
# on time step 19844 (time=99.22), 0.0136518 s/step
# Meep progress: 100.495/200.0 = 50.2% done in 288.5s, 285.6s to go
# on time step 20119 (time=100.595), 0.0145515 s/step
# Meep progress: 101.8/200.0 = 50.9% done in 292.5s, 282.1s to go
# on time step 20381 (time=101.905), 0.0152965 s/step
# Meep progress: 103.205/200.0 = 51.6% done in 296.5s, 278.1s to go
# on time step 20661 (time=103.305), 0.0142967 s/step
# Meep progress: 104.61500000000001/200.0 = 52.3% done in 300.5s, 274.0s to go
# on time step 20949 (time=104.745), 0.0139247 s/step
# Meep progress: 106.16/200.0 = 53.1% done in 304.5s, 269.2s to go
# on time step 21258 (time=106.29), 0.0129671 s/step
# Meep progress: 107.53/200.0 = 53.8% done in 308.5s, 265.3s to go
# on time step 21532 (time=107.66), 0.0146083 s/step
# Meep progress: 108.99000000000001/200.0 = 54.5% done in 312.5s, 261.0s to go
# on time step 21824 (time=109.12), 0.0137139 s/step
# Meep progress: 110.46000000000001/200.0 = 55.2% done in 316.5s, 256.6s to go
# on time step 22115 (time=110.575), 0.0137641 s/step
# Meep progress: 111.735/200.0 = 55.9% done in 320.5s, 253.2s to go
# on time step 22361 (time=111.805), 0.0163185 s/step
# Meep progress: 112.92/200.0 = 56.5% done in 324.5s, 250.3s to go
# on time step 22609 (time=113.045), 0.0161352 s/step
# Meep progress: 114.215/200.0 = 57.1% done in 328.6s, 246.8s to go
# on time step 22870 (time=114.35), 0.0153856 s/step
# Meep progress: 115.575/200.0 = 57.8% done in 332.6s, 242.9s to go
# on time step 23143 (time=115.715), 0.0146781 s/step
# Meep progress: 116.925/200.0 = 58.5% done in 336.6s, 239.1s to go
# on time step 23406 (time=117.03), 0.0152545 s/step
# Meep progress: 118.33500000000001/200.0 = 59.2% done in 340.6s, 235.0s to go
# on time step 23693 (time=118.465), 0.0139811 s/step
# Meep progress: 119.815/200.0 = 59.9% done in 344.6s, 230.6s to go
# on time step 23986 (time=119.93), 0.0137075 s/step
# Meep progress: 121.125/200.0 = 60.6% done in 348.6s, 227.0s to go
# on time step 24251 (time=121.255), 0.0151178 s/step
# Meep progress: 122.63/200.0 = 61.3% done in 352.6s, 222.5s to go
# on time step 24549 (time=122.745), 0.013455 s/step
# Meep progress: 123.845/200.0 = 61.9% done in 356.6s, 219.3s to go
# on time step 24793 (time=123.965), 0.0164572 s/step
# Meep progress: 125.14/200.0 = 62.6% done in 360.6s, 215.7s to go
# on time step 25058 (time=125.29), 0.0151104 s/step
# Meep progress: 126.51/200.0 = 63.3% done in 364.6s, 211.8s to go
# on time step 25327 (time=126.635), 0.0149235 s/step
# Meep progress: 127.87/200.0 = 63.9% done in 368.6s, 207.9s to go
# on time step 25603 (time=128.015), 0.0145423 s/step
# Meep progress: 129.235/200.0 = 64.6% done in 372.6s, 204.0s to go
# on time step 25876 (time=129.38), 0.0146622 s/step
# Meep progress: 130.55/200.0 = 65.3% done in 376.7s, 200.4s to go
# on time step 26137 (time=130.685), 0.0153643 s/step
# Meep progress: 131.885/200.0 = 65.9% done in 380.7s, 196.6s to go
# on time step 26408 (time=132.04), 0.0147712 s/step
# Meep progress: 133.21/200.0 = 66.6% done in 384.7s, 192.9s to go
# on time step 26667 (time=133.335), 0.0154732 s/step
# Meep progress: 134.505/200.0 = 67.3% done in 388.7s, 189.3s to go
# on time step 26926 (time=134.63), 0.0154467 s/step
# Meep progress: 135.745/200.0 = 67.9% done in 392.7s, 185.9s to go
# on time step 27181 (time=135.905), 0.015716 s/step
# Meep progress: 137.09/200.0 = 68.5% done in 396.7s, 182.0s to go
# on time step 27443 (time=137.215), 0.0152986 s/step
# Meep progress: 138.385/200.0 = 69.2% done in 400.7s, 178.4s to go
# on time step 27702 (time=138.51), 0.0154819 s/step
# Meep progress: 139.75/200.0 = 69.9% done in 404.7s, 174.5s to go
# on time step 27975 (time=139.875), 0.0146594 s/step
# Meep progress: 141.125/200.0 = 70.6% done in 408.7s, 170.5s to go
# on time step 28257 (time=141.285), 0.0142221 s/step
# Meep progress: 142.665/200.0 = 71.3% done in 412.7s, 165.9s to go
# on time step 28562 (time=142.81), 0.013166 s/step
# Meep progress: 144.06/200.0 = 72.0% done in 416.7s, 161.8s to go
# on time step 28842 (time=144.21), 0.0142983 s/step
# Meep progress: 145.37/200.0 = 72.7% done in 420.8s, 158.1s to go
# on time step 29103 (time=145.515), 0.0153696 s/step
# Meep progress: 146.69/200.0 = 73.3% done in 424.8s, 154.4s to go
# on time step 29365 (time=146.825), 0.0153158 s/step
# Meep progress: 148.135/200.0 = 74.1% done in 428.8s, 150.1s to go
# on time step 29661 (time=148.305), 0.0135518 s/step
# Meep progress: 149.605/200.0 = 74.8% done in 432.8s, 145.8s to go
# on time step 29956 (time=149.78), 0.0135882 s/step
# Meep progress: 151.07500000000002/200.0 = 75.5% done in 436.8s, 141.5s to go
# on time step 30249 (time=151.245), 0.013693 s/step
# Meep progress: 152.46/200.0 = 76.2% done in 440.8s, 137.4s to go
# on time step 30527 (time=152.635), 0.014393 s/step
# Meep progress: 154.01500000000001/200.0 = 77.0% done in 444.8s, 132.8s to go
# on time step 30838 (time=154.19), 0.0128818 s/step
# Meep progress: 155.38/200.0 = 77.7% done in 448.8s, 128.9s to go
# on time step 31112 (time=155.56), 0.0146379 s/step
# Meep progress: 156.92000000000002/200.0 = 78.5% done in 452.8s, 124.3s to go
# on time step 31414 (time=157.07), 0.0132812 s/step
# Meep progress: 158.23/200.0 = 79.1% done in 456.8s, 120.6s to go
# on time step 31682 (time=158.41), 0.0149538 s/step
# Meep progress: 159.61/200.0 = 79.8% done in 460.8s, 116.6s to go
# on time step 31955 (time=159.775), 0.0146597 s/step
# Meep progress: 161.065/200.0 = 80.5% done in 464.8s, 112.4s to go
# on time step 32246 (time=161.23), 0.0137871 s/step
# Meep progress: 162.47/200.0 = 81.2% done in 468.8s, 108.3s to go
# on time step 32524 (time=162.62), 0.0144319 s/step
# Meep progress: 163.865/200.0 = 81.9% done in 472.8s, 104.3s to go
# on time step 32804 (time=164.02), 0.0143128 s/step
# Meep progress: 165.345/200.0 = 82.7% done in 476.9s, 99.9s to go
# on time step 33099 (time=165.495), 0.0135893 s/step
# Meep progress: 166.645/200.0 = 83.3% done in 480.9s, 96.2s to go
# on time step 33359 (time=166.795), 0.0154158 s/step
# Meep progress: 167.97/200.0 = 84.0% done in 484.9s, 92.5s to go
# on time step 33632 (time=168.16), 0.0146714 s/step
# Meep progress: 169.35/200.0 = 84.7% done in 488.9s, 88.5s to go
# on time step 33906 (time=169.53), 0.014606 s/step
# Meep progress: 170.725/200.0 = 85.4% done in 492.9s, 84.5s to go
# on time step 34183 (time=170.915), 0.0144701 s/step
# Meep progress: 172.11/200.0 = 86.1% done in 496.9s, 80.5s to go
# on time step 34452 (time=172.26), 0.0148951 s/step
# Meep progress: 173.32/200.0 = 86.7% done in 500.9s, 77.1s to go
# on time step 34696 (time=173.48), 0.0164388 s/step
# Meep progress: 174.73/200.0 = 87.4% done in 504.9s, 73.0s to go
# on time step 34984 (time=174.92), 0.0139037 s/step
# Meep progress: 176.13/200.0 = 88.1% done in 508.9s, 69.0s to go
# on time step 35262 (time=176.31), 0.0144194 s/step
# Meep progress: 177.655/200.0 = 88.8% done in 512.9s, 64.5s to go
# on time step 35571 (time=177.855), 0.0129595 s/step
# Meep progress: 179.16/200.0 = 89.6% done in 516.9s, 60.1s to go
# on time step 35865 (time=179.325), 0.0136142 s/step
# Meep progress: 180.675/200.0 = 90.3% done in 520.9s, 55.7s to go
# on time step 36172 (time=180.86), 0.0130302 s/step
# Meep progress: 182.055/200.0 = 91.0% done in 525.0s, 51.7s to go
# on time step 36449 (time=182.245), 0.0144728 s/step
# Meep progress: 183.35/200.0 = 91.7% done in 529.0s, 48.0s to go
# on time step 36708 (time=183.54), 0.0154881 s/step
# Meep progress: 184.89000000000001/200.0 = 92.4% done in 533.0s, 43.6s to go
# on time step 37016 (time=185.08), 0.0129987 s/step
# Meep progress: 186.25/200.0 = 93.1% done in 537.0s, 39.6s to go
# on time step 37280 (time=186.4), 0.0151576 s/step
# Meep progress: 187.48/200.0 = 93.7% done in 541.0s, 36.1s to go
# on time step 37527 (time=187.635), 0.0162565 s/step
# Meep progress: 188.71/200.0 = 94.4% done in 545.0s, 32.6s to go
# on time step 37781 (time=188.905), 0.0157861 s/step
# Meep progress: 190.095/200.0 = 95.0% done in 549.0s, 28.6s to go
# on time step 38052 (time=190.26), 0.0147994 s/step
# Meep progress: 191.41/200.0 = 95.7% done in 553.0s, 24.8s to go
# on time step 38314 (time=191.57), 0.0153068 s/step
# Meep progress: 192.64000000000001/200.0 = 96.3% done in 557.0s, 21.3s to go
# on time step 38560 (time=192.8), 0.0162631 s/step
# Meep progress: 193.945/200.0 = 97.0% done in 561.0s, 17.5s to go
# on time step 38822 (time=194.11), 0.0152959 s/step
# Meep progress: 195.26/200.0 = 97.6% done in 565.0s, 13.7s to go
# on time step 39084 (time=195.42), 0.0152761 s/step
# Meep progress: 196.48000000000002/200.0 = 98.2% done in 569.1s, 10.2s to go
# on time step 39327 (time=196.635), 0.0165103 s/step
# Meep progress: 197.78/200.0 = 98.9% done in 573.1s, 6.4s to go
# on time step 39588 (time=197.94), 0.0153352 s/step
# Meep progress: 199.07500000000002/200.0 = 99.5% done in 577.1s, 2.7s to go
# on time step 39846 (time=199.23), 0.0155605 s/step
# run 0 finished at t = 200.0 (40000 timesteps)

# %%
filename = "bent_waveguide.mp4"
fps = 10
Animate.to_mp4(fps,filename)
Video(filename, embed=True)
# Out:
# Generating MP4...
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
sim.reset_meep()
cell = mp.Vector3(16,40,0)
geometry = [mp.Block(mp.Vector3(12,1,mp.inf),
                     center=mp.Vector3(-2.5,-3.5),
                     material=mp.Medium(epsilon=12)),
            mp.Block(mp.Vector3(1,42,mp.inf),
                     center=mp.Vector3(3.5,17),
                     material=mp.Medium(epsilon=12))]
sim.cell_size = cell
sim.geometry = geometry
sim.geometry_center = mp.Vector3(0,12,0)

sim.run(until=400)

plt.figure(dpi=150)
sim.plot2D(fields=mp.Ez)
plt.show()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00564289 s
# Working in 2D dimensions.
# Computational cell is 16 x 40 x 0 with resolution 100
#      block, center = (-2.5,-3.5,0)
#           size (12,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (3.5,17,0)
#           size (1,42,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
# time for set_epsilon = 10.7783 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=400.0)
# Meep progress: 0.24/400.0 = 0.1% done in 4.1s, 6755.4s to go
# on time step 48 (time=0.24), 0.0840374 s/step
# Meep progress: 0.5700000000000001/400.0 = 0.1% done in 8.1s, 5675.2s to go
# on time step 114 (time=0.57), 0.0612658 s/step
# Meep progress: 0.855/400.0 = 0.2% done in 12.1s, 5660.4s to go
# on time step 171 (time=0.855), 0.0704142 s/step
# Meep progress: 1.18/400.0 = 0.3% done in 16.1s, 5450.4s to go
# on time step 237 (time=1.185), 0.0614367 s/step
# Meep progress: 1.455/400.0 = 0.4% done in 20.2s, 5519.4s to go
# on time step 292 (time=1.46), 0.0734676 s/step
# Meep progress: 1.7650000000000001/400.0 = 0.4% done in 24.2s, 5464.7s to go
# on time step 354 (time=1.77), 0.0655273 s/step
# Meep progress: 2.035/400.0 = 0.5% done in 28.2s, 5520.8s to go
# on time step 408 (time=2.04), 0.0741652 s/step
# Meep progress: 2.345/400.0 = 0.6% done in 32.3s, 5474.0s to go
# on time step 470 (time=2.35), 0.0652225 s/step
# Meep progress: 2.665/400.0 = 0.7% done in 36.3s, 5417.2s to go
# on time step 534 (time=2.67), 0.0629267 s/step

# %%
vals = []

def get_slice(sim):
    vals.append(sim.get_array(center=mp.Vector3(0,-3.5), size=mp.Vector3(16,0), component=mp.Ez))

sim.reset_meep()
sim.run(mp.at_beginning(mp.output_epsilon),
        mp.at_every(0.6, get_slice),
        until=200)

plt.figure(dpi=150)
plt.imshow(vals, interpolation='spline36', cmap='RdBu')
plt.axis('off')
plt.show()

# %%
import meep as mp
import numpy as np
from numpy import linalg as LA
import matplotlib.pyplot as plt

n = 3.4
w = 1
r = 1
pad = 4
dpml = 2

sxy = 2*(r+w+pad+dpml)
cell_size = mp.Vector3(sxy,sxy)

pml_layers = [mp.PML(dpml)]

nonpml_vol = mp.Volume(mp.Vector3(), size=mp.Vector3(sxy-2*dpml,sxy-2*dpml))

geometry = [mp.Cylinder(radius=r+w, material=mp.Medium(index=n)),
            mp.Cylinder(radius=r)]

fcen = 0.118

src = [mp.Source(mp.ContinuousSource(fcen),
                 component=mp.Ez,
                 center=mp.Vector3(r+0.1)),
       mp.Source(mp.ContinuousSource(fcen),
                 component=mp.Ez,
                 center=mp.Vector3(-(r+0.1)),
                 amplitude=-1)]

symmetries = [mp.Mirror(mp.X,phase=-1),
              mp.Mirror(mp.Y,phase=+1)]

sim = mp.Simulation(cell_size=cell_size,
                    geometry=geometry,
                    sources=src,
                    resolution=10,
                    force_complex_fields=True,
                    symmetries=symmetries,
                    boundary_layers=pml_layers)

num_tols = 5
tols = np.power(10, np.arange(-8.0,-8.0-num_tols,-1.0))
ez_dat = np.zeros((122,122,num_tols), dtype=np.complex_)

for i in range(num_tols):
    sim.init_sim()
    sim.solve_cw(tols[i], 10000, 10)
    ez_dat[:,:,i] = sim.get_array(vol=nonpml_vol, component=mp.Ez)

err_dat = np.zeros(num_tols-1)
for i in range(num_tols-1):
    err_dat[i] = LA.norm(ez_dat[:,:,i]-ez_dat[:,:,num_tols-1])

plt.figure(dpi=150)
plt.loglog(tols[:num_tols-1], err_dat, 'bo-');
plt.xlabel("frequency-domain solver tolerance");
plt.ylabel("L2 norm of error in fields");
plt.show()

eps_data = sim.get_array(vol=nonpml_vol, component=mp.Dielectric)
ez_data = np.real(ez_dat[:,:,num_tols-1])

plt.figure()
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.imshow(ez_data.transpose(), interpolation='spline36', cmap='RdBu', alpha=0.9)
plt.axis('off')
plt.show()

if np.all(np.diff(err_dat) < 0):
    print("PASSED solve_cw test: error in the fields is decreasing with increasing resolution")
else:
    print("FAILED solve_cw test: error in the fields is NOT decreasing with increasing resolution")

sim.reset_meep()

df = 0.08
src = [mp.Source(mp.GaussianSource(fcen,fwidth=df),
                 component=mp.Ez,
                 center=mp.Vector3(r+0.1)),
       mp.Source(mp.GaussianSource(fcen,fwidth=df),
                 component=mp.Ez,
                 center=mp.Vector3(-(r+0.1)),
                 amplitude=-1)]

sim = mp.Simulation(cell_size=mp.Vector3(sxy,sxy),
                    geometry=geometry,
                    sources=src,
                    resolution=10,
                    symmetries=symmetries,
                    boundary_layers=pml_layers)

dft_obj = sim.add_dft_fields([mp.Ez], fcen, 0, 1, where=nonpml_vol)

sim.run(until_after_sources=100)

eps_data = sim.get_array(vol=nonpml_vol, component=mp.Dielectric)
ez_data = np.real(sim.get_dft_array(dft_obj, mp.Ez, 0))

plt.figure()
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.imshow(ez_data.transpose(), interpolation='spline36', cmap='RdBu', alpha=0.9)
plt.axis('off')
plt.show()

# %%
import meep as mp

from random import random
from random import seed
seed(1)
def field_func(p):
    rr = random() - 0.5
    return rr

Lx = .05; Ly = .04; Lz = .03 # [M]
Nx = 25; Ny = 20; Nz = 15;   #
vals = []
cell = mp.Vector3(Lx,Ly,Lz)
geometry = [mp.Block(cell,
                     center=mp.Vector3(),
                     material=mp.Medium(epsilon=12))]

sim = mp.Simulation(cell_size=mp.Vector3(Lx,Ly,Lz),
                    resolution=50,
                    geometry=geometry)

sim.initialize_field(mp.Ex, field_func)
sim.initialize_field(mp.Ey, field_func)
sim.initialize_field(mp.Ez, field_func)


eps_data = sim.get_efield_z()


d#ef get_slice(sim):
 #   vals.append(sim.get_array(center=mp.Vector3(0,-3.5), size=mp.Vector3(16,0), component=mp.Ez))

def print_field(sim):
    Ex = sim.get_field_point(mp.Ex, mp.Vector3(4,4,4)).real
    Ey = sim.get_field_point(mp.Ey, mp.Vector3(4,4,4)).real
    Ez = sim.get_field_point(mp.Ez, mp.Vector3(4,4,4)).real
    vals.append(Ex+Ey+Ez)
    #print("field:, {}, {}".format(sim.meep_time(), fp))

sim.run(mp.after_time(100, print_field),until=200)

# %%
eps_data = sim.get_efield_z()
print((eps_data).shape)
